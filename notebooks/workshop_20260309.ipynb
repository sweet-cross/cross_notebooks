# %% [markdown]
# <a href="https://colab.research.google.com/github/sweet-cross/cross_notebooks/blob/main/cross_notebooks/workshop_20260309.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
if 'google.colab' in sys.modules:
    # Installs the repo as a package, along with its dependencies
    # !pip install -q git+https://github.com/sweet-cross/cross_notebooks.git
